# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ### Data

# %%
mex = xr.open_dataset("../eolica-nas/2_simulaciones/CF_latam/sp_mx.nc")
mex_sp = mex.__xarray_dataarray_variable__
mex_lats = mex.latitude
mex_lons = mex.longitude

# Lo que supongo será el sur
# sur = xr.open_dataset("../eolica-nas/2_simulaciones/CF_latam/sp_sur.nc")
# sur_sp = sp_sur.__xarray_dataarray_variable__
# sur_lats = sur.latitude
# sur_lons = sur.longitude

# %% [markdown]
# ### Mexico

# %%
plt.figure(figsize=(12,10))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines(resolution="10m", alpha=0.3)
ax.add_feature(cfeature.BORDERS, alpha=0.3)
ax.add_feature(cfeature.STATES.with_scale("10m"), alpha=0.3)


p = ax.pcolormesh(mex_lons, mex_lats, mex_sp, vmin=-1, vmax=1, transform=ccrs.PlateCarree(), cmap="RdBu")
# p = ax.pcolormesh(latam.longitude, latam.latitude, latam.ws100[190], cmap='jet', vmin=0, vmax=14, transform=ccrs.PlateCarree())
# ax.add_feature(cfeature.OCEAN)
plt.colorbar(p, shrink=0.3)

# %% [markdown]
# ### Todo el dominio

# %%
# plt.figure(figsize=(6,12))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines(resolution="10m", alpha=0.3)
ax.add_feature(cfeature.BORDERS, alpha=0.3)
ax.add_feature(cfeature.STATES.with_scale("10m"), alpha=0.3)


p = ax.pcolormesh(mex_lons, mex_lats, mex_sp, vmin=-1, vmax=1, transform=ccrs.PlateCarree(), cmap="RdBu")
# ax.pcolormesh(sur_lons, sur_lats, sur_sp, vmin=-1, vmax=1, transform=ccrs.PlateCarree(), cmap="RdBu")
ax.add_feature(cfeature.OCEAN)
# ax.quiver(longitude, latitude, u100[0], v100[0], scale=250)
plt.colorbar(p, shrink=0.4)
